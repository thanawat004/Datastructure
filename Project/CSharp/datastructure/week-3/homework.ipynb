# %%
def convert_seconds(total_seconds):
    # 1 ชั่วโมง = 3600 วินาที
    hours = total_seconds // 3600

    # หาจำนวนวินาทีที่เหลือจากการตัดเป็นชั่วโมง
    remaining_seconds = total_seconds % 3600

    # 1 นาที = 60 วินาที
    minutes = remaining_seconds // 60

    # เศษที่เหลือคือวินาที
    seconds = remaining_seconds % 60

    return hours, minutes, seconds


try:
    user_input = input("กรุณาป้อนจำนวนวินาทีที่ต้องการแปลง: ")
    input_seconds = int(user_input)

    # เรียกใช้ฟังก์ชัน
    h, m, s = convert_seconds(input_seconds)

    print(f"{input_seconds} วินาที = {h} ชั่วโมง {m} นาที {s} วินาที")

except ValueError:
    # กรณีผู้ใช้ป้อนค่าที่ไม่ใช่ตัวเลข
    print("ใส่เป็นตัวเลขนะ! กรุณาป้อนเฉพาะตัวเลขเท่านั้น")
# Out:
# 9000 วินาที = 2 ชั่วโมง 30 นาที 0 วินาที
